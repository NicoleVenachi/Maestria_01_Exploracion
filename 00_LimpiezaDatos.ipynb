# %% [markdown]
# # Imports
# ---

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Cargar Data
# ___

# %%
df_data = pd.read_excel('ds_pb.xlsx', sheet_name='Regression_Dataset')
df_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [2], line 2
#       1 _deepnote_current_table_attrs = '{"pageSize":100,"pageIndex":0,"sortBy":[],"filters":[]}'
# ----> 2 df_data = pd.read_excel('ds_pb.xlsx', sheet_name='Regression_Dataset')
#       3 df_data
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/util/_decorators.py:299, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     294     msg = (
#     295         f"Starting with Pandas version {version} all arguments of "
#     296         f"{func.__name__}{arguments} will be keyword-only"
#     297     )
#     298     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299 return func(*args, **kwargs)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/io/excel/_base.py:336, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334 if not isinstance(io, ExcelFile):
#     335     should_close = True
# --> 336     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337 elif engine and engine != io.engine:
#     338     raise ValueError(
#     339         "Engine should not be specified when passing "
#     340         "an ExcelFile - ExcelFile already has the engine set"
#     341     )
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/io/excel/_base.py:1140, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1137 self.engine = engine
#    1138 self.storage_options = storage_options
# -> 1140 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/io/excel/_xlrd.py:24, in XlrdReader.__init__(self, filepath_or_buffer, storage_options)
#      13 """
#      14 Reader using xlrd engine.
#      15
#    (...)
#      21     passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#      22 """
#      23 err_msg = "Install xlrd >= 1.0.0 for Excel support"
# ---> 24 import_optional_dependency("xlrd", extra=err_msg)
#      25 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/compat/_optional.py:109, in import_optional_dependency(name, extra, raise_on_missing, on_version)
#     107 except ImportError:
#     108     if raise_on_missing:
# --> 109         raise ImportError(msg) from None
#     110     else:
#     111         return None
#
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.

# %% [markdown]
# # Análisis exploratorio
# ___

# %% [markdown]
# > Comprobar conformidad en los datos (i.e., Dtype) y conocer features

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Compound                    132 non-null    object
#  1   xBi(Me1Me2)O3               132 non-null    float64
#  2   xPT                         132 non-null    float64
#  3   Tolerance_Factor            132 non-null    float64
#  4   Ionic_Displacements         132 non-null    float64
#  5   Ferroelectric_Tc_in_Kelvin  132 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 6.3+ KB

# %% [markdown]
# > Conocer las categorías a clasificar

# %%
df_data['Compound'].unique()
# Out:
# array(['BiFeO3-PT', 'BiZnTiO3-PT', 'Bi(MgW)O3-PT', 'Bi(MgNb)O3-PT',
#        'BiInO3-PT', 'BiScO3-PT', 'Bi(ZnNb)O3-PT', 'Bi(MgTi)O3-PT',
#        'BiLuO3-PT', 'BiGaO3-PT', 'Bi(GaSc)O3-PT', 'Bi(NiNb)O3-PT',
#        'Bi(ScFe)O3-PT', 'Bi(ZnW)O3-PT', 'Bi(ScIn)O3-PT', 'BiMnO3-PT',
#        'BiAlO3-PT', 'Bi(ZnZr)O3-PT', 'Bi(MgZr)O3-PT', 'Bi(ScGa)O3-PT',
#        'Bi(CoFe)O3-PT'], dtype=object)

# %% [markdown]
# > Resumen info de variables numéricas

# %%
df_data.describe()
# Out:
#        xBi(Me1Me2)O3         xPT  Tolerance_Factor  Ionic_Displacements  \
# count     132.000000  132.000000        132.000000           132.000000
# mean        0.282964    0.717036          1.003184             0.082206
# std         0.174792    0.174792          0.015325             0.010201
# min         0.000000    0.102000          0.962463             0.072827
# 25%         0.149837    0.625000          0.989669             0.075874
# 50%         0.251000    0.749000          1.005635             0.078292
# 75%         0.375000    0.850162          1.016191             0.084941
# max         0.898000    1.000000          1.027204             0.129287
#
#        Ferroelectric_Tc_in_Kelvin
# count                  132.000000
# mean                   741.983530
# std                    106.885708
# min                    430.036000
# 25%                    703.585750
# 50%                    752.023500
# 75%                    784.968000
# max                   1100.543000

# %% [markdown]
# # Limpieza de datos
# ___

# %% [markdown]
# > Eliminar categorías no relevantes para la clasificación

# %% [markdown]
# - Elimino

# %%
#df_data = df_data.drop(['Chemical formula', 'In literature', 'a [ang]', 'b [ang]', 'c [ang]',  'alpha [deg]', 'beta [deg]', 'gamma [deg]'], axis = 1)

# %% [markdown]
# - Compruebo

# %%
#df_data.columns

# %% [markdown]
# > Eliminar datos con categoría desconocida (además, conformidad, pues varios descriptores tienen missing info en esos casos)

# %% [markdown]
# - Valido cuantos hay

# %% [markdown]
# - Los elimino

# %% [markdown]
# - Compruebo que ya no esten

# %% [markdown]
# > Ajustar tipos de datos (Asegurar conformidad)

# %% [markdown]
# - Verifico ahora que features carecen conformidad

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Compound                    132 non-null    object
#  1   xBi(Me1Me2)O3               132 non-null    float64
#  2   xPT                         132 non-null    float64
#  3   Tolerance_Factor            132 non-null    float64
#  4   Ionic_Displacements         132 non-null    float64
#  5   Ferroelectric_Tc_in_Kelvin  132 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 6.3+ KB

# %% [markdown]
# - Cambio tipos de datos en features incoherentes no problemáticos

# %% [markdown]
# - Analizo features problemáticos y decido

# %% [markdown]
# - Cambio tipos de datos en features incoherentes problemáticos (voy a borrar missing registers)

# %% [markdown]
# > Eliminar Nulos/ Nans

# %% [markdown]
# - Compruebo Nulos

# %%
df_data.isnull().sum()
# Out:
# Compound                      0
# xBi(Me1Me2)O3                 0
# xPT                           0
# Tolerance_Factor              0
# Ionic_Displacements           0
# Ferroelectric_Tc_in_Kelvin    0
# dtype: int64

# %% [markdown]
# - Elimino Nulos

# %% [markdown]
# - Compruebo y veo con cuántos registros quedé

# %% [markdown]
# > Eliminar registros duplicados

# %% [markdown]
# - Eliminar duplicados

# %%
df_data.drop_duplicates(inplace = True)

# %% [markdown]
# - Comprobar si algún registro fue eliminado

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132 entries, 0 to 131
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Compound                    132 non-null    object
#  1   xBi(Me1Me2)O3               132 non-null    float64
#  2   xPT                         132 non-null    float64
#  3   Tolerance_Factor            132 non-null    float64
#  4   Ionic_Displacements         132 non-null    float64
#  5   Ferroelectric_Tc_in_Kelvin  132 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# > Normalizar variables categóricas

# %% [markdown]
# - Comprobar si ciertas categorías de cada variable categórica están normalizadas

# %% [markdown]
# # Exportar dataset clean
# ___

# %%
df_data.to_csv("ds_pb.csv", sep=',')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1238d720-2ec8-40e1-ad99-9d2cd1c1fe59' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
